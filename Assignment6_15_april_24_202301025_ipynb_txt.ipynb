# %% [markdown]
# <a href="https://colab.research.google.com/github/JatinGarg01/Big-Data/blob/main/Assignment6_15_april_24_202301025_ipynb_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[1], [2], [3], [4], [5],[6],[7]])
y = np.array([9,8,10,12,11,13,14])

model = LinearRegression()
model.fit(X, y)

intercept = model.intercept_
slope = model.coef_[0]

y_pred = model.predict(X)

plt.scatter(X, y, color='red')
plt.plot(X, y_pred, color='blue')
plt.xlabel('X')
plt.ylabel('y')
plt.title('SLR')
plt.show()

# %%
#x=[2,4,6,8]
#y=[3,7,5,10]
x=[1,2,3,4,5,6,7]
y=[9,8,10,12,11,13,14]
n=len(x)
sum_xy=0
sum_xx=0
j=0
for i in x:
  sum_xx+=i*i
  sum_xy+=i*y[j]
  j+=1

b = (n*sum_xy-sum(x)*sum(y))/(n*sum_xx-sum(x)**2)
#a=mean_y-b*mean_x
a=sum(y)/n - b*(sum(x)/n)
#Y=b0+b1*X
print("y =",a," + ",b,"X")

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
Y1=[]
for i in range(n):
    Y = a + b * x[i]
    Y1.append(Y)
    plt.scatter(x[i], y[i],color='blue')  # original data points
    plt.scatter(x[i], Y, color='red')  # points on the regression line
plt.title('SLR')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# y = 7.285714285714286  +  0.9285714285714286 X
# Text(0, 0.5, 'y')
